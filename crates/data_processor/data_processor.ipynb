# %%
import data_processor
import numpy as np
import matplotlib.pyplot as plt
import time
# %load_ext autoreload
# %autoreload 2

# %%
file = data_processor.F32Data.load("../compute_core/slope_angle.bin")
# plt.contourf(d2, cmap='viridis')
# plt.colorbar()

# %%
d = (file.data)
plt.contourf(d, cmap='viridis')
plt.colorbar()
print("Slope angle min:", np.min(d))
print("Slope angle max:", np.max(d))
print("Slope angle mean:", np.mean(d))
# Out:
# Slope angle min: 33.998203
# Slope angle max: 34.00012
# Slope angle mean: 33.999996

# %%
file = data_processor.F32Data.load("../compute_core/slope_aspect.bin")
d = file.data
plt.contourf(file.data, cmap='viridis')
plt.colorbar()
print("Slope aspect min:", np.min(d))
print("Slope aspect max:", np.max(d))
# Out:
# Slope aspect min: 90.0
# Slope aspect max: 90.0

# %%
file = data_processor.F32Data.load("../compute_core/profile_curvature.bin")
d = file.data
plt.contourf(file.data, cmap='viridis')
plt.colorbar()
print("Slope aspect min:", np.min(d))
print("Slope aspect max:", np.max(d))
# Out:
# Slope aspect min: -2.895822581194807e-05
# Slope aspect max: 2.895822581194807e-05
