# %%
import requests
import json
import os
import pandas as pd
import time
import matplotlib.pyplot as plt
from screeninfo import get_monitors
import requests

from tqdm import tqdm
import os
import requests
import json

mplstyle_url = "https://gitlab.com/Grommi/mplstyle/-/raw/main/mjr_dark.mplstyle?ref_type=heads"
response = requests.get(mplstyle_url)
with open('mjr_dark.mplstyle', 'wb') as f:
    f.write(response.content)
plt.style.use(['mjr_dark.mplstyle'])
for m in get_monitors():
    print(m)
    if m.is_primary:
    # small screen 286mm
        if m.width_mm == 286:
            print("Laptop")
            plt.rcParams["figure.figsize"] = (9,5)
        else:
            print("Another Monitor")
            plt.rcParams["figure.figsize"] = (8,4)

# %load_ext autoreload
# %autoreload 2
# Directory containing the JSON files
data_dir = 'data'
incidents_dir = 'data/incidents'
# Out:
# Monitor(x=807, y=2160, width=2736, height=1824, width_mm=260, height_mm=173, name='\\\\.\\DISPLAY1', is_primary=False)
# Monitor(x=0, y=0, width=3840, height=2160, width_mm=621, height_mm=341, name='\\\\.\\DISPLAY2', is_primary=True)
# Another Monitor
# Monitor(x=3840, y=230, width=1080, height=1920, width_mm=296, height_mm=527, name='\\\\.\\DISPLAY3', is_primary=False)

# %%
# download summaries of specified seasons
season_starts = [2025]
for season_start in season_starts:
    url = f"https://lawis.at/lawis_api/v2_3/incident/?startDate={season_start}-09-01&endDate={season_start + 1}-09-01&_=1740497482175"
    page = requests.get(url)
    data = page.content
    os.makedirs("data", exist_ok=True)
    with open(f"data/lawis_{season_start}_{season_start + 1}.json", "wb") as f:
        f.write(data)
    time.sleep(1)

# %%
# Load all lawis season summaries
dfs = []

# Loop through each file in the directory
for file_name in os.listdir(data_dir):
    if file_name.endswith('.json'):
        file_path = os.path.join(data_dir, file_name)
        with open(file_path, 'r') as f:
            data = json.load(f)
            df = pd.json_normalize(data)
            dfs.append(df)

# Concatenate all DataFrames into one
df_seasons = pd.concat(dfs, ignore_index=True)
df_seasons
# Out:
#       incident_id                datum  country_id  region_id  subregion_id  \
# 0            6745  1992-12-12 00:00:00           1          1           160
# 1            6746  1993-01-27 00:00:00           1          1           167
# 2            6747  1993-01-31 00:00:00           1          1           172
# 3            6748  1993-02-21 00:00:00           1          1           175
# 4            6749  1993-02-21 00:00:00           1          1           158
# ...           ...                  ...         ...        ...           ...
# 4847        11589  2026-04-03 13:38:00           1          1           173
# 4848        11592  2026-04-16 16:39:00           1          1           177
# 4849        11590  2026-02-01 14:30:00           1          1           179
# 4850        11591  2026-04-15 12:00:00           1          6           268
# 4851        11582  2026-04-12 16:40:00           1          5           140
#
#                                         ort  elevation   latitude  longitude  \
# 0                   Hafelekar - Diretissima     2200.0  47.395000  11.260000
# 1                     Moostal - Rendlgebiet     2000.0  47.104665  10.263416
# 2     Hochtennboden - Schigeb. Axamer Lizum     2350.0  47.174721  11.287931
# 3                      Aschau - Spiessnägel     1700.0  47.359404  12.306106
# 4                  Neunerköpfle - Usseralpe     1862.0  47.483574  10.540690
# ...                                     ...        ...        ...        ...
# 4847                        Schwarze Pfanne        NaN  47.105500  11.653170
# 4848                             Karleskopf        NaN  46.936330  10.895330
# 4849                   Allerleigrubenspitze     2090.0  46.995090  11.422020
# 4850                              Gamskogel     2170.0  47.273610  13.446070
# 4851     Dachstein - Kleiner Koppenkarstein     2690.0  47.465440  13.632570
#
#       incline  aspect_id  danger_id  n_injured  n_dead n_uninjured  \
# 0         NaN        6.0        NaN        1.0     0.0         NaN
# 1        40.0        7.0        4.0        0.0     2.0         NaN
# 2        35.0        3.0        4.0        0.0     1.0         NaN
# 3         NaN        2.0        5.0        0.0     1.0         NaN
# 4        45.0        8.0        5.0        0.0     1.0         NaN
# ...       ...        ...        ...        ...     ...         ...
# 4847      NaN        9.0        2.0        0.0     0.0         1.0
# 4848      NaN        9.0        3.0        1.0     0.0         NaN
# 4849     45.0        8.0        3.0        0.0     0.0         1.0
# 4850     35.0        8.0        2.0        NaN     NaN         NaN
# 4851     45.0        6.0        2.0        0.0     0.0         3.0
#
#      involved_sum involved  valid_time  revision
# 0             NaN      yes        True         1
# 1             NaN      yes        True         1
# 2             NaN      yes        True         1
# 3             NaN      yes        True         1
# 4             NaN      yes        True         1
# ...           ...      ...         ...       ...
# 4847          1.0      yes        True         1
# 4848          NaN      yes        True         1
# 4849          1.0      yes        True         2
# 4850          NaN  unknown        True         3
# 4851          3.0      yes        True         2
#
# [4852 rows x 19 columns]

# %%
# Download all incidents
incidents_dir = 'data/incidents'
os.makedirs(incidents_dir, exist_ok=True)

# Loop through each incident_id in the DataFrame
for incident_id in tqdm(df_seasons.incident_id, desc="Downloading incidents"):
    path = f"{incidents_dir}/{incident_id}.json"
    if not os.path.exists(path):
        url = f"https://lawis.at/lawis_api/public/incident/{incident_id}"
        response = requests.get(url)
        response.encoding = "utf-8"
        data = response.json()
        with open(path, "w", encoding='utf-8') as f:
            f.write(json.dumps(data, indent=2, ensure_ascii=False))
# Out:
# Downloading incidents: 100%|██████████| 4852/4852 [02:19<00:00, 34.78it/s]

# %%
# Load all lawis incidents from disk and write to CSV
dfis = []

# Loop through each file in the directory
for file_name in tqdm(os.listdir(incidents_dir), desc="Loading incidents"):
    if file_name.endswith('.json'):
        file_path = os.path.join(incidents_dir, file_name)
        with open(file_path, 'r', encoding='utf-8') as f:
            data = json.load(f)
            dfi = pd.json_normalize(data)
            dfis.append(dfi)

# Concatenate all DataFrames into one
dfi = pd.concat(dfis, ignore_index=True)
dfi.to_csv('data/lawis_incidents_all.csv', index=False, encoding='utf-8')
dfi
# Out:
# Loading incidents: 100%|██████████| 4853/4853 [00:08<00:00, 555.34it/s]
#          id  valid_time                                             images  \
# 0     10000        True  [http://localhost/lawis_api/v2_3/files/inciden...
# 1     10001        True                                                NaN
# 2     10002        True                                                NaN
# 3     10003        True                                                NaN
# 4     10004        True  [http://localhost/lawis_api/v2_3/files/inciden...
# ...     ...         ...                                                ...
# 4848   9988        True  [http://localhost/lawis_api/v2_3/files/inciden...
# 4849   9989        True                                                NaN
# 4850   9996        True                                                NaN
# 4851   9997        True                                                NaN
# 4852   9999        True  [http://localhost/lawis_api/v2_3/files/inciden...
#
#                            date              reported.date  \
# 0     2021-01-15T08:58:00+01:00  2021-01-15T16:12:51+01:00
# 1     2021-01-14T14:30:00+01:00  2021-01-15T17:09:43+01:00
# 2     2021-01-15T12:00:00+01:00  2021-01-16T08:13:46+01:00
# 3     2021-01-15T11:00:00+01:00  2021-01-16T08:15:57+01:00
# 4     2021-01-15T12:00:00+01:00  2021-01-16T09:13:53+01:00
# ...                         ...                        ...
# 4848  2020-12-31T11:28:00+01:00  2021-01-12T16:48:59+01:00
# 4849  2021-01-11T14:00:00+01:00  2021-01-13T10:00:09+01:00
# 4850  2021-01-15T10:58:00+01:00  2021-01-15T11:22:35+01:00
# 4851  2021-01-15T13:40:00+01:00  2021-01-15T15:50:39+01:00
# 4852  2021-01-15T10:45:00+01:00  2021-01-15T15:59:48+01:00
#
#            reported.name                    reported.email involved.dead  \
# 0           Patrick Gams               pats.gams@gmail.com             0
# 1        Stifter Florian  lawinenwarndienst.post@ooe.gv.at             0
# 2     Arnold Studeregger     arnold.studeregger@zamg.ac.at             0
# 3     Arnold Studeregger     arnold.studeregger@zamg.ac.at             0
# 4                 Sedlak                        slp@hzs.sk             0
# ...                  ...                               ...           ...
# 4848       Thomas Aigner     thomas.aigner1@stud.sbg.ac.at             0
# 4849           LWD Tirol                lawine@tirol.gv.at             0
# 4850           LWD Tirol                lawine@tirol.gv.at             0
# 4851      LWD Steiermark       lawine@lawine-steiermark.at             1
# 4852      LWD Steiermark       lawine@lawine-steiermark.at             0
#
#      involved.injured involved.uninjured  ... location.country.id  \
# 0                   0                  0  ...                   1
# 1                   1                  1  ...                   1
# 2                   0                  0  ...                   1
# 3                   0                  0  ...                   1
# 4                   0                  2  ...                  12
# ...               ...                ...  ...                 ...
# 4848                0                  0  ...                   1
# 4849                0                  1  ...                   1
# 4850                0                  1  ...                   1
# 4851                1                  0  ...                   1
# 4852                0                  1  ...                   1
#
#      location.country.code location.country.text  location.region.id  \
# 0                       AT            Österreich                   5
# 1                       AT            Österreich                   7
# 2                       AT            Österreich                   5
# 3                       AT            Österreich                   5
# 4                       SK             Slovensko                  38
# ...                    ...                   ...                 ...
# 4848                    AT            Österreich                   6
# 4849                    AT            Österreich                   1
# 4850                    AT            Österreich                   1
# 4851                    AT            Österreich                   5
# 4852                    AT            Österreich                   5
#
#      location.region.text  location.subregion.id  \
# 0              Steiermark                    146
# 1          Oberösterreich                    253
# 2              Steiermark                    148
# 3              Steiermark                    148
# 4               Slovensko                     58
# ...                   ...                    ...
# 4848             Salzburg                     90
# 4849                Tirol                    180
# 4850                Tirol                    172
# 4851           Steiermark                    146
# 4852           Steiermark                    143
#
#                 location.subregion.text  involved.equipment  \
# 0                   Südl. Wölzer Tauern                 NaN
# 1                             Nordalpen                 NaN
# 2                      Eisenerzer Alpen                  []
# 3                      Eisenerzer Alpen                 NaN
# 4                             Slovensko                 NaN
# ...                                 ...                 ...
# 4848                     Niedere Tauern                 NaN
# 4849           Nördl. Zillertaler Alpen                 NaN
# 4850  Nördl. Ötztaler- & Stubaier Alpen                 NaN
# 4851                Südl. Wölzer Tauern                  []
# 4852                Schladminger Tauern                  []
#
#                                                comments  not_buried
# 0                                                   NaN         NaN
# 1                                                   NaN         NaN
# 2                                                   NaN         NaN
# 3                                                   NaN         NaN
# 4     vystup troch skialpinistov zo Skalnateho plesa...         NaN
# ...                                                 ...         ...
# 4848  Fernauslösung über wenige Meter während wenige...         NaN
# 4849  Meldung der Leitstelle - derzeit noch keine nä...         NaN
# 4850                                                NaN         NaN
# 4851  Gesamtes Triebschneepaket auf Altschnee abgega...         NaN
# 4852                                                NaN         NaN
#
# [4853 rows x 54 columns]

# %%
# Load all incident details from CSV
dfi = pd.read_csv('data/lawis_incidents_all.csv', encoding='utf-8')
df = dfi[[
    'id',
    'date',
    'involved.dead',
    'involved.injured',
    'involved.uninjured',
    'involved.sweeped',
    'involved.buried_partial',
    'involved.buried_total',
    'involved.ascent_descent.text',
    'danger.rating.id',
    'avalanche.extent.length',
    'avalanche.extent.width',
    'avalanche.breakheight',
    'avalanche.type.text',
    'avalanche.size.text',
    'avalanche.release.text',
    'avalanche.humidity.text',
    'location.elevation',
    'location.longitude',
    'location.latitude',
    'location.slope_angle',
    'location.aspect.id',
]]
df = df.rename(columns={
    'involved.dead': 'dead',
    'involved.injured': 'injured',
    'involved.uninjured': 'uninjured',
    'involved.sweeped': 'sweeped',
    'involved.buried_partial': 'buried_partial',
    'involved.buried_total': 'buried_total',
    'involved.ascent_descent.text': 'ascent_descent',
    'danger.rating.id': 'danger_id',
    'avalanche.extent.length': 'length',
    'avalanche.extent.width': 'width',
    'avalanche.breakheight': 'slab_height',
    'avalanche.type.text': 'avalanche_type',
    'avalanche.size.text': 'size',
    'avalanche.release.text': 'release',
    'avalanche.humidity.text': 'humidity',
    'location.elevation': 'elevation',
    'location.longitude': 'longitude',
    'location.latitude': 'latitude',
    'location.slope_angle': 'slope_angle',
    'location.aspect.id': 'aspect',
})

df.to_csv('data/lawis_incidents.csv', index=False, encoding='utf-8')
# df.date = pd.to_datetime(df['date'])
print(f"Total incidents: {len(df)} ({df.date.min()} - {df.date.max()})")
df
# Out:
# Total incidents: 4853 (1992-11-17T00:00:00+01:00 - 2026-04-16T16:39:00+02:00)
#          id                       date  dead  injured  uninjured  sweeped  \
# 0     10000  2021-01-15T08:58:00+01:00   0.0      0.0        0.0      0.0
# 1     10001  2021-01-14T14:30:00+01:00   0.0      1.0        1.0      2.0
# 2     10002  2021-01-15T12:00:00+01:00   0.0      0.0        0.0      0.0
# 3     10003  2021-01-15T11:00:00+01:00   0.0      0.0        0.0      0.0
# 4     10004  2021-01-15T12:00:00+01:00   0.0      0.0        2.0      2.0
# ...     ...                        ...   ...      ...        ...      ...
# 4848   9988  2020-12-31T11:28:00+01:00   0.0      0.0        0.0      0.0
# 4849   9989  2021-01-11T14:00:00+01:00   0.0      0.0        1.0      0.0
# 4850   9996  2021-01-15T10:58:00+01:00   0.0      0.0        1.0      0.0
# 4851   9997  2021-01-15T13:40:00+01:00   1.0      1.0        0.0      0.0
# 4852   9999  2021-01-15T10:45:00+01:00   0.0      0.0        1.0      0.0
#
#       buried_partial  buried_total ascent_descent  danger_id  ...  \
# 0                0.0           0.0         ascent        3.0  ...
# 1                1.0           1.0         ascent        3.0  ...
# 2                0.0           0.0        descent        3.0  ...
# 3                0.0           0.0        unknown        3.0  ...
# 4                0.0           2.0         ascent        3.0  ...
# ...              ...           ...            ...        ...  ...
# 4848             0.0           0.0        descent        3.0  ...
# 4849             0.0           0.0        unknown        2.0  ...
# 4850             0.0           0.0        descent        4.0  ...
# 4851             0.0           0.0            NaN        3.0  ...
# 4852             0.0           0.0            NaN        3.0  ...
#
#       slab_height  avalanche_type                 size     release humidity  \
# 0           100.0            slab   1: small avalanche     unknown      dry
# 1             NaN            slab              unknown         NaN  unknown
# 2             NaN            slab              unknown  artificial      NaN
# 3             NaN            slab              unknown  artificial      dry
# 4            50.0            slab   1: small avalanche  artificial      dry
# ...           ...             ...                  ...         ...      ...
# 4848         10.0            slab   1: small avalanche  artificial      dry
# 4849          NaN            slab  2: medium avalanche  artificial      dry
# 4850         70.0            slab  2: medium avalanche  artificial      dry
# 4851          NaN            slab   3: large avalanche  artificial      dry
# 4852          NaN            slab              unknown  artificial      dry
#
#      elevation longitude  latitude  slope_angle  aspect
# 0       2025.0  14.32961  47.26257         30.0     4.0
# 1       1580.0  14.28506  47.64233         30.0     8.0
# 2       1700.0  14.82266  47.48985         35.0     2.0
# 3       1900.0  14.85188  47.48853         30.0     8.0
# 4       2190.0  20.21776  49.18796         39.0     3.0
# ...        ...       ...       ...          ...     ...
# 4848    2056.0  13.47404  47.23459         33.0     8.0
# 4849    3100.0  11.63086  47.02469         35.0     4.0
# 4850    2000.0  11.28543  47.19600         38.0     3.0
# 4851    2150.0  14.15511  47.23573         35.0     3.0
# 4852    2300.0  13.94448  47.21804         30.0     5.0
#
# [4853 rows x 22 columns]

# %%
print("Incidents with at least one death:", df.dead[df.dead > 0].count())
print(f"Incidents with more than one death: {df.dead[df.dead > 1].count()} ({(df.dead[df.dead > 1].count() / df.dead[df.dead > 0].count()) * 100:.2f}%)")

print("Incidents with at least one injury:", df.injured[df.injured > 0].count())
print(f"Incidents with more than one injury: {df.injured[df.injured > 1].count()} ({(df.injured[df.injured > 1].count() / df.injured[df.injured > 0].count()) * 100:.2f}%)")
# Out:
# Incidents with at least one death: 479
# Incidents with more than one death: 86 (17.95%)
# Incidents with at least one injury: 838
# Incidents with more than one injury: 165 (19.69%)

# %%
fig, ax = plt.subplots()
counts, bins, patches = ax.hist(df.slope_angle, bins=[v - 2.5 for v in range(25, 61, 5)], edgecolor='black')
# df[df.involved_sum > 0].incline.hist(bins=[v - 2.5 for v in range(30, 60, 5)], ax=ax)
color_danger = ["#cbd859", "#f1e60d", "#f49717", "#e51c20", "black"]
colors = ["#4de54b", "#f2e42c", "#ffa92d", "#ff302d", "#ff4ff9", "#b745fd", "#550089"]
ax.set(xlabel='Slope Angle (°)', ylabel='Number of incidents')
for patch, color in zip(patches, colors):
    patch.set_facecolor(color)
df.slope_angle.dropna().sort_values(ascending=False).head(11)
# Out:
# 4387    90.0
# 2271    80.0
# 4740    80.0
# 520     80.0
# 3123    80.0
# 1204    60.0
# 891     60.0
# 3001    60.0
# 497     60.0
# 3293    60.0
# 2840    55.0
# Name: slope_angle, dtype: float64

# %%
fig, ax = plt.subplots()
counts, bins, patches = ax.hist(df.danger_id[(df.danger_id < 7)],bins=[v - .5 for v in range(1, 7)], edgecolor='black', density=False)
ax.set(xlabel='Avalanche Risk', ylabel='Number of incidents', xticks=range(1, 6), xticklabels=['Low', 'Moderate', 'Considerable', 'High', 'Very High'])
for patch, color in zip(patches, colors):
    patch.set_facecolor(color)
df.danger_id.value_counts()
# Out:
# danger_id
# 3.0    1936
# 2.0    1175
# 4.0     277
# 1.0     157
# 7.0      48
# 5.0      15
# Name: count, dtype: int64

# %%
fig, ax = plt.subplots()
counts, bins, patches = ax.hist(df.elevation, edgecolor='black', bins=40, density=True)
ax.set(xlabel='Elevation (m)', ylabel='Relative number of Incidents', xlim=(800, 3800))
import seaborn as sns
sns.kdeplot(df.elevation, bw_adjust=1, fill=False, ax=ax)
# Out:
# <Axes: xlabel='Elevation (m)', ylabel='Relative number of Incidents'>

# %%
fig, ax = plt.subplots()
counts, bins, patches = ax.hist(df.width[df.width <= 200], edgecolor='black', density=False, bins=20)
ax.set(xlabel='Width (m)', ylabel='Number of Incidents')
ax.text(0.95, 0.95, f'Max Width: {df.width.max():.0f} m', transform=ax.transAxes, ha='right', va='top', fontsize=10)
# Out:
# Text(0.95, 0.95, 'Max Width: 850 m')

# %%
fig, ax = plt.subplots()
counts, bins, patches = ax.hist(df.length[df.length <= 1500], edgecolor='black', density=False, bins=20)
ax.set(xlabel='Length (m)', ylabel='Number of Incidents')
ax.text(0.95, 0.95, f'Max Length: {df.length.max():.0f} m', transform=ax.transAxes, ha='right', va='top', fontsize=10)
# Out:
# 3060.0

# %%
fig, ax = plt.subplots()
counts, bins, patches = ax.hist(df.slab_height[df.slab_height < 500], edgecolor='black', density=False, bins=15)
ax.set(xlabel='Slab Height (cm)', ylabel='Number of Incidents')
ax.text(0.95, 0.95, f'Max Slab Height: {df.slab_height.max():.0f} cm', transform=ax.transAxes, ha='right', va='top', fontsize=10)
df.slab_height.dropna().sort_values()
# Out:
# 22         1.0
# 164        1.0
# 165        1.0
# 167        1.0
# 308        1.0
#          ...
# 3005     400.0
# 95       400.0
# 2600     500.0
# 139     1980.0
# 1063    3255.0
# Name: slab_height, Length: 2055, dtype: float64

# %%
import numpy as np
aspect_id_to_text = ["N", "NE", "E", "SE", "S", "SW", "W", "NW"]
theta = np.linspace(0.0, 2 * np.pi, 8, endpoint=False)
fig, ax = plt.subplots(subplot_kw={'projection': 'polar'})
ax.bar(theta, df.aspect[df.aspect < 9].value_counts().sort_index().values, width=np.pi/4,edgecolor='black')
ax.set_xticklabels(aspect_id_to_text)
ax.set_theta_zero_location('N')
ax.set_theta_direction(-1)
ax.set_yticks([250, 500])
# Out:
# C:\Users\magge\AppData\Local\Temp\ipykernel_25296\804537403.py:6: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(aspect_id_to_text)
# [<matplotlib.projections.polar.RadialTick at 0x1ecec79b110>,
#  <matplotlib.projections.polar.RadialTick at 0x1ecec703c50>]

# %%
fig, ax = plt.subplots()
ax.scatter(df.longitude, df.latitude, s=1, c=df.aspect, cmap='tab20', alpha=0.5)
ax.set(xlim=(9.47996951665, 16.9796667823), ylim=(46.4318173285, 48))
# Out:
# [(9.47996951665, 16.9796667823), (46.4318173285, 48.0)]

# %%
for season in range(2010, 2025):
    df_year = df[(df.date >= f"{season}-09-01") & (df.date < f"{season + 1}-09-01")]
    fig, ax = plt.subplots()
    counts, bins, patches = ax.hist(df_year.danger_id[(df_year.danger_id < 6)],bins=[v - .5 for v in range(1, 6)], edgecolor='black', density=False)
    ax.set(title=f"Season {season}/{season + 1}", xlabel='Avalanche Risk', ylabel='Number of incidents', xticks=range(1, 5), xticklabels=['Low', 'Moderate', 'Considerable', 'High'])
    for patch, color in zip(patches, colors):
        patch.set_facecolor(color)

# %%
"{season}-09-01"
# Out:
# '{season}-09-01'

# %%
df
# Out:
#          id                       date dead injured uninjured sweeped  \
# 0     10000  2021-01-15T08:58:00+01:00    0       0         0       0
# 1     10001  2021-01-14T14:30:00+01:00    0       1         1       2
# 2     10002  2021-01-15T12:00:00+01:00    0       0         0       0
# 3     10003  2021-01-15T11:00:00+01:00    0       0         0       0
# 4     10004  2021-01-15T12:00:00+01:00    0       0         2       2
# ...     ...                        ...  ...     ...       ...     ...
# 4373   9988  2020-12-31T11:28:00+01:00    0       0         0       0
# 4374   9989  2021-01-11T14:00:00+01:00    0       0         1       0
# 4375   9996  2021-01-15T10:58:00+01:00    0       0         1       0
# 4376   9997  2021-01-15T13:40:00+01:00    1       1         0       0
# 4377   9999  2021-01-15T10:45:00+01:00    0       0         1       0
#
#      buried_partial buried_total ascent_descent danger_id  ... slab_height  \
# 0                 0            0         ascent         3  ...         100
# 1                 1            1         ascent         3  ...        None
# 2                 0            0        descent         3  ...        None
# 3                 0            0        unknown         3  ...        None
# 4                 0            2         ascent         3  ...          50
# ...             ...          ...            ...       ...  ...         ...
# 4373              0            0        descent         3  ...          10
# 4374              0            0        unknown         2  ...        None
# 4375              0            0        descent         4  ...          70
# 4376              0            0            NaN         3  ...        None
# 4377              0            0            NaN         3  ...        None
#
#      avalanche_type                 size     release humidity elevation  \
# 0              slab   1: small avalanche     unknown      dry    2025.0
# 1              slab              unknown         NaN  unknown    1580.0
# 2              slab              unknown  artificial      NaN    1700.0
# 3              slab              unknown  artificial      dry    1900.0
# 4              slab   1: small avalanche  artificial      dry    2190.0
# ...             ...                  ...         ...      ...       ...
# 4373           slab   1: small avalanche  artificial      dry    2056.0
# 4374           slab  2: medium avalanche  artificial      dry    3100.0
# 4375           slab  2: medium avalanche  artificial      dry    2000.0
# 4376           slab   3: large avalanche  artificial      dry    2150.0
# 4377           slab              unknown  artificial      dry    2300.0
#
#      longitude  latitude  slope_angle  aspect
# 0     14.32961  47.26257         30.0     4.0
# 1     14.28506  47.64233         30.0     8.0
# 2     14.82266  47.48985         35.0     2.0
# 3     14.85188  47.48853         30.0     8.0
# 4     20.21776  49.18796         39.0     3.0
# ...        ...       ...          ...     ...
# 4373  13.47404  47.23459         33.0     8.0
# 4374  11.63086  47.02469         35.0     4.0
# 4375  11.28543  47.19600         38.0     3.0
# 4376  14.15511  47.23573         35.0     3.0
# 4377  13.94448  47.21804         30.0     5.0
#
# [4378 rows x 22 columns]
